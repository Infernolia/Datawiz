# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib notebook

# %%
dataset = pd.read_csv('WagesClean2.csv') #Reading data

# %%
dataset.head()
# Out:
#    Unnamed: 0                             EmployerName  MinPositionSalary  \
# 0       89259     Gujarat Forensic Sciences University           22879.56
# 1       82407  Maharaja Sayajirao University of Baroda           22879.56
# 2      103432                  Sardar Patel University           22879.56
# 3       34291              Dharamsinh Desai University           31200.00
# 4       27651   Dr. Babasaheb Ambedkar Open University           49512.00
#
#    MaxPositionSalary  OvertimePay  LumpSumPay  OtherPay  \
# 0          291194.40          0.0         0.0      0.00
# 1           38749.56          0.0         0.0    596.85
# 2           38749.56          0.0         0.0   1040.13
# 3           48888.00          0.0         0.0   5399.60
# 4           66192.00          0.0         0.0   2697.00
#
#    EmployeesRetirementCostCovered  HealthDentalVision  \
# 0                             0.0                0.00
# 1                             0.0                0.00
# ...

# %%
dataset.rename( columns={'Unnamed: 0':'ID'}, inplace=True )

# %%
dataset.head()
# Out:
#        ID                             EmployerName  MinPositionSalary  \
# 0   89259     Gujarat Forensic Sciences University           22879.56
# 1   82407  Maharaja Sayajirao University of Baroda           22879.56
# 2  103432                  Sardar Patel University           22879.56
# 3   34291              Dharamsinh Desai University           31200.00
# 4   27651   Dr. Babasaheb Ambedkar Open University           49512.00
#
#    MaxPositionSalary  OvertimePay  LumpSumPay  OtherPay  \
# 0          291194.40          0.0         0.0      0.00
# 1           38749.56          0.0         0.0    596.85
# 2           38749.56          0.0         0.0   1040.13
# 3           48888.00          0.0         0.0   5399.60
# 4           66192.00          0.0         0.0   2697.00
#
#    EmployeesRetirementCostCovered  HealthDentalVision  \
# 0                             0.0                0.00
# 1                             0.0                0.00
# ...

# %%
dataset.rename( columns={'EmployerCounty':'Location'}, inplace=True )

# %%
dataset.head()
# Out:
#        ID                             EmployerName  MinPositionSalary  \
# 0   89259     Gujarat Forensic Sciences University           22879.56
# 1   82407  Maharaja Sayajirao University of Baroda           22879.56
# 2  103432                  Sardar Patel University           22879.56
# 3   34291              Dharamsinh Desai University           31200.00
# 4   27651   Dr. Babasaheb Ambedkar Open University           49512.00
#
#    MaxPositionSalary  OvertimePay  LumpSumPay  OtherPay  \
# 0          291194.40          0.0         0.0      0.00
# 1           38749.56          0.0         0.0    596.85
# 2           38749.56          0.0         0.0   1040.13
# 3           48888.00          0.0         0.0   5399.60
# 4           66192.00          0.0         0.0   2697.00
#
#    EmployeesRetirementCostCovered  HealthDentalVision  \
# 0                             0.0                0.00
# 1                             0.0                0.00
# ...

# %%
dataset['Day'] = np.random.randint(1,28,size=(len(dataset),1))

# %%
dataset.head()
# Out:
#        ID                             EmployerName  MinPositionSalary  \
# 0   89259     Gujarat Forensic Sciences University           22879.56
# 1   82407  Maharaja Sayajirao University of Baroda           22879.56
# 2  103432                  Sardar Patel University           22879.56
# 3   34291              Dharamsinh Desai University           31200.00
# 4   27651   Dr. Babasaheb Ambedkar Open University           49512.00
#
#    MaxPositionSalary  OvertimePay  LumpSumPay  OtherPay  \
# 0          291194.40          0.0         0.0      0.00
# 1           38749.56          0.0         0.0    596.85
# 2           38749.56          0.0         0.0   1040.13
# 3           48888.00          0.0         0.0   5399.60
# 4           66192.00          0.0         0.0   2697.00
#
#    EmployeesRetirementCostCovered  HealthDentalVision  \
# 0                             0.0                0.00
# 1                             0.0                0.00
# ...

# %%
dataset['Month'] = np.random.randint(1,12,size=(len(dataset),1))

# %%
dataset.head()
# Out:
#        ID                             EmployerName  MinPositionSalary  \
# 0   89259     Gujarat Forensic Sciences University           22879.56
# 1   82407  Maharaja Sayajirao University of Baroda           22879.56
# 2  103432                  Sardar Patel University           22879.56
# 3   34291              Dharamsinh Desai University           31200.00
# 4   27651   Dr. Babasaheb Ambedkar Open University           49512.00
#
#    MaxPositionSalary  OvertimePay  LumpSumPay  OtherPay  \
# 0          291194.40          0.0         0.0      0.00
# 1           38749.56          0.0         0.0    596.85
# 2           38749.56          0.0         0.0   1040.13
# 3           48888.00          0.0         0.0   5399.60
# 4           66192.00          0.0         0.0   2697.00
#
#    EmployeesRetirementCostCovered  HealthDentalVision  \
# 0                             0.0                0.00
# 1                             0.0                0.00
# ...

# %%
dataset['Year'] = np.random.randint(1950,1990,size=(len(dataset),1))

# %%
dataset.head()
# Out:
#        ID                             EmployerName  MinPositionSalary  \
# 0   89259     Gujarat Forensic Sciences University           22879.56
# 1   82407  Maharaja Sayajirao University of Baroda           22879.56
# 2  103432                  Sardar Patel University           22879.56
# 3   34291              Dharamsinh Desai University           31200.00
# 4   27651   Dr. Babasaheb Ambedkar Open University           49512.00
#
#    MaxPositionSalary  OvertimePay  LumpSumPay  OtherPay  \
# 0          291194.40          0.0         0.0      0.00
# 1           38749.56          0.0         0.0    596.85
# 2           38749.56          0.0         0.0   1040.13
# 3           48888.00          0.0         0.0   5399.60
# 4           66192.00          0.0         0.0   2697.00
#
#    EmployeesRetirementCostCovered  HealthDentalVision  \
# 0                             0.0                0.00
# 1                             0.0                0.00
# ...

# %%
dataset['Location']=dataset['Location'].sample(frac=0.73)

# %%
dataset.head()
# Out:
#        ID                             EmployerName  MinPositionSalary  \
# 0   89259     Gujarat Forensic Sciences University           22879.56
# 1   82407  Maharaja Sayajirao University of Baroda           22879.56
# 2  103432                  Sardar Patel University           22879.56
# 3   34291              Dharamsinh Desai University           31200.00
# 4   27651   Dr. Babasaheb Ambedkar Open University           49512.00
#
#    MaxPositionSalary  OvertimePay  LumpSumPay  OtherPay  \
# 0          291194.40          0.0         0.0      0.00
# 1           38749.56          0.0         0.0    596.85
# 2           38749.56          0.0         0.0   1040.13
# 3           48888.00          0.0         0.0   5399.60
# 4           66192.00          0.0         0.0   2697.00
#
#    EmployeesRetirementCostCovered  HealthDentalVision  \
# 0                             0.0                0.00
# 1                             0.0                0.00
# ...

# %%
dataset['LumpSumPay']=dataset['LumpSumPay'].sample(frac=0.89)

# %%
dataset.head()
# Out:
#        ID                             EmployerName  MinPositionSalary  \
# 0   89259     Gujarat Forensic Sciences University           22879.56
# 1   82407  Maharaja Sayajirao University of Baroda           22879.56
# 2  103432                  Sardar Patel University           22879.56
# 3   34291              Dharamsinh Desai University           31200.00
# 4   27651   Dr. Babasaheb Ambedkar Open University           49512.00
#
#    MaxPositionSalary  OvertimePay  LumpSumPay  OtherPay  \
# 0          291194.40          0.0         0.0      0.00
# 1           38749.56          0.0         0.0    596.85
# 2           38749.56          0.0         0.0   1040.13
# 3           48888.00          0.0         0.0   5399.60
# 4           66192.00          0.0         0.0   2697.00
#
#    EmployeesRetirementCostCovered  HealthDentalVision  \
# 0                             0.0                0.00
# 1                             0.0                0.00
# ...

# %%
dataset
# Out:
#            ID                                       EmployerName  \
# 0       89259               Gujarat Forensic Sciences University
# 1       82407            Maharaja Sayajirao University of Baroda
# 2      103432                            Sardar Patel University
# 3       34291                        Dharamsinh Desai University
# 4       27651             Dr. Babasaheb Ambedkar Open University
# 5       69894                   Gujarat Technological University
# 6       22586               Bhakta Kavi Narsinh Mehta University
# 7      103623                            Sardar Patel University
# 8       64510                                 Gujarat University
# 9       24429               Bhakta Kavi Narsinh Mehta University
# 10      87653                    Navsari Agricultural University
# 11      34030                        Dharamsinh Desai University
# 12     108314                              Saurashtra University
# ...

# %%
dataset.to_csv('WagesClean3.csv')

# %%
dataset['TotalWages'].corr(dataset['ID'])
# Out:
# -0.0451046826799322

# %%
dataset['TotalWages'].corr(dataset['MinPositionSalary'])
# Out:
# 0.7561340314203202

# %%
dataset['TotalWages'].corr(dataset['MaxPositionSalary'])
# Out:
# 0.6229165774862471

# %%
dataset['TotalWages'].corr(dataset['OvertimePay'])
# Out:
# 0.13681912793629808

# %%
dataset['TotalWages'].corr(dataset['LumpSumPay'])
# Out:
# 0.16438168190951566

# %%
dataset['TotalWages'].corr(dataset['OtherPay'])
# Out:
# 0.33108101811043367

# %%
dataset['TotalWages'].corr(dataset['EmployeesRetirementCostCovered'])
# Out:
# 0.08504489551010481

# %%
dataset['TotalWages'].corr(dataset['HealthDentalVision'])
# Out:
# 0.751259915989827

# %%
dataset['TotalWages'].corr(dataset['Year'])
# Out:
# 0.006414746213655481
